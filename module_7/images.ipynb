# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %%
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['figure.facecolor'] = 'white'

# %% [markdown]
# # Урок 2_1

# %%
ax1 = plt.subplot(121)
ax = plt.subplot(122, projection='3d')

x = np.linspace(0, 10, 1000)
y = x ** 2

ax1.plot(x, y)
ax1.set_title('Функция от одного аргумента')

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, # cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
ax.set_title('Функция от двух аргументов')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

# plt.show()

plt.savefig('../images/function_intro.png')
# Out:
# C:\Users\koval\AppData\Local\Temp/ipykernel_21804/2987284982.py:30: MatplotlibDeprecationWarning: Starting from Matplotlib 3.6, colorbar() will steal space from the mappable's axes, rather than from the current axes, to place the colorbar.  To silence this warning, explicitly pass the 'ax' argument to colorbar().
#   fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['figure.facecolor'] = 'white'
ax1 = plt.subplot(121)
ax2 = plt.subplot(122)

x = np.linspace(0, 10, 1000)
y = x ** 2

ax1.plot(x, y, color='blue')
ax1.set_title('Непрерывная функция')

x1 = np.linspace(0, 5, 500)
z1 = 2 * x1
x2 = np.linspace(5, 10, 500)
z2 = 11 + x1 * 0.5

ax2.plot(x1, z1, color='blue')
ax2.plot(x2, z2, color='blue')
ax2.set_title('Разрыв в точке 5')

plt.savefig('../images/continuous_func.png')

# %%
x = np.linspace(-5, 5)
y = np.abs(x)

plt.plot(x, y)
plt.title('В точке 0 можно провести несколько касательных')

x1 = np.linspace(-5, 5)
y1 = 0 * x1
y2 = 0.5 * x1
y3 = -0.5 * x1
plt.plot(x1, y1, color='r', linewidth=0.5)
plt.plot(x1, y2, color='r', linewidth=0.5)
plt.plot(x1, y3, color='r', linewidth=0.5)

plt.legend(['f(x)=|x|', 'касательные'])

plt.savefig('../images/diff_func.png')

# %%
def f(x):
    return x * x

x0 = 2
delta_x = 0.000001
(f(x0 + delta_x) - f(x0)) / delta_x
# Out:
# 4.0000010006480125

# %%
x = np.linspace(-5, 5)
y = f(x)
plt.plot(x, y)
plt.scatter([2], [4], color='r')

x_tang = np.linspace(-2, 5)
y_tang = 4 * x_tang - 4
plt.plot(x_tang, y_tang)

plt.legend(['f(x)', 'касательная'])
plt.savefig('../images/geometric_diff.png')

# %%
x = np.linspace(-5, 5)
y = f(x)
plt.plot(x, y)
plt.scatter([-2], [4], color='r')

x_tang = np.linspace(-5, 2)
y_tang = -4 * x_tang - 4
plt.plot(x_tang, y_tang)

plt.legend(['f(x)', 'касательная'])
plt.savefig('../images/geometric_diff_negative.png')

# %%
x = np.random.uniform(20, 120, size=1000)
y = np.random.normal(0, 1000, size=1000) + x * 200 + 1000
plt.scatter(x, y)
plt.title('Зависимость стоимости квартиры от ее площади')
plt.xlabel('Площадь, м2')
plt.ylabel('Стоимость, тыс. р.')

plt.savefig('../images/flat_price.png')

# %%
x = np.random.uniform(20, 120, size=1000)
y = np.random.normal(0, 1000, size=1000) + x * 200 + 1000
plt.scatter(x, y)
plt.title('Зависимость стоимости квартиры от ее площади')
plt.xlabel('Площадь, м2')
plt.ylabel('Стоимость, тыс. р.')

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x.reshape(-1, 1), y)
y1 = model.predict(x.reshape(-1, 1))
plt.plot(x, y1, color='r')

plt.legend(['прогноз'])
plt.savefig('../images/flat_price_prediction.png')

# %% [markdown]
# # Урок 2_2

# %%
def f(x):
    return x * x

def f_prime(x):
    return 2 * x

x = np.linspace(-10, 10)
y = f(x)

plt.plot(x, y)

x_points = np.linspace(-4, 4, 5)
y_points = f(x_points)
plt.scatter(x_points, y_points, color='r')

for x_p in x_points:
    x = np.linspace(x_p - 5, x_p + 5, 1000)
    y_p = f_prime(x_p) * (x - x_p) + f(x_p)
    plt.plot(x, y_p, linewidth=0.5, color='r')
    
plt.legend(['f(x)', 'касательные'])

plt.savefig('../images/parabola_tang.png')

# %%
def f(x):
    return -x * x

def f_prime(x):
    return -2 * x

x = np.linspace(-10, 10)
y = f(x)

plt.plot(x, y)

x_points = np.linspace(-4, 4, 5)
y_points = f(x_points)
plt.scatter(x_points, y_points, color='r')

for x_p in x_points:
    x = np.linspace(x_p - 5, x_p + 5, 1000)
    y_p = f_prime(x_p) * (x - x_p) + f(x_p)
    plt.plot(x, y_p, linewidth=0.5, color='r')
    
plt.legend(['f(x)', 'касательные'])

plt.savefig('../images/parabola_tang_reversed.png')

# %%
def f(x):
    return 6 * x ** 2 - x ** 3

def f_prime(x):
    return 12 * x - 3 * x ** 2

x = np.linspace(-15, 15, 1000)
y = f(x)

plt.plot(x, y)
plt.title('Пример точки перегиба')

x_0 = 2
y_0 = f(x_0)

plt.scatter([x_0], [y_0], color='r')

x_t = np.linspace(x_0 - 12, x_0 + 12, 1000)
y_t = f_prime(x_0) * (x_t - x_0) + f(x_0)
plt.plot(x_t, y_t, color='r')

plt.legend(['f(x)', 'касательная'])

plt.savefig('../images/inflection_point.png')

# %% [markdown]
# # Урок 2_3

# %%
def f(x):
    return x ** 2

x = np.linspace(0, 5, 1000)
y = f(x)

plt.plot(x, y)

a, b = 2, 3

x1 = np.linspace(a, b, 100)
y1 = f(x1)
y2 = 0 * x1
plt.fill_between(x1, y1, y2, alpha=0.5)

plt.scatter([a, b], [f(a), f(b)], color='r')

plt.plot(x, 0 * x, color='black')
plt.plot(0 * x, x * 6, color='black')

plt.title('Площадь между точками 2 и 3')

plt.savefig('../images/area_under_curve.png')

# %% [markdown]
# # Урок 3

# %%
def f(x, y):
    return x * x + y * y - 2 * x + 3 * y - 25

def grad_f(x, y):
    grad_x = 2 * x - 2
    grad_y = 2 * y + 3
    return np.array([grad_x, grad_y])

x0 = np.array([15, 10])
x_old = x0
# Эти параметры можно менять и смотреть на результат
eps = 10e-6
learning_rate = 0.1
max_steps = 100

i = 0
while np.linalg.norm(grad_f(x_old[0], x_old[1])) > eps:
    # Обновляем x
    x_new = x_old - learning_rate * grad_f(x_old[0], x_old[1])
    x_old = x_new
    
    # Увеличиваем счетчик
    i += 1
    # Проверяем, нужно ли выходить из цикла
    if i == max_steps:
        break

print(x_new, f(x_new[0], x_new[1]), i)
# Out:
# [ 1.0000036  -1.49999704] -28.2499999999783 68
